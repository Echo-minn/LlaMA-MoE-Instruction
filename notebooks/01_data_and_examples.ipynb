# %% [markdown]
# # Llama-AgentOS: Data and Examples
#
# This notebook explores `neulab/agent-data-collection` and shows formatted training examples.
#
# Outline:
# - Load a handful of conversations
# - Visualize role distributions and turns
# - Format into (input, target) pairs
# - Show tool-call markup examples
